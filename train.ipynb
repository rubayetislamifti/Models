# %%
import os
import time
import copy
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils, models
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from tqdm import tqdm
import cv2
from torchvision import transforms, datasets
from Datasets.train_data import SaliencyDataset

from utils.loss_function import SaliencyLoss
#from utils.data_process import MyDataset
from TranSalNet_Res import TranSalNet

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
train_dataset = SaliencyDataset(
    image_dir=r"E:\Digital Image Processing\Assignment 3\TranSalNet-Res\Datasets\Images\images",
    saliency_dir=r"E:\Digital Image Processing\Assignment 3\TranSalNet-Res\Datasets\TD_FixMaps",
    fixation_dir=r"E:\Digital Image Processing\Assignment 3\TranSalNet-Res\Datasets\TD_FixPts",  
    transform=transform
)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = TranSalNet()
model = model.to(device)

# %%
optimizer = optim.Adam(model.parameters(),lr=1e-5)
scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
loss_fn = SaliencyLoss()

save_dir = 'E:\Digital Image Processing\Assignment 3\TranSalNet-Res\Datasets\Saliency_map_TD'
os.makedirs(save_dir, exist_ok=True)

'''Training'''
best_model_wts = copy.deepcopy(model.state_dict())
num_epochs =10  
best_loss = 100
for k,v in model.named_parameters():
    print('{}: {}'.format(k, v.requires_grad))

total_loss = 0.0

for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch + 1, num_epochs))
    print('-' * 10)
    model.train()
    running_loss = 0.0

    for images, TD_maps, TD_FixPts in train_loader:
        images, TD_maps, TD_FixPts = images.to(device), TD_maps.to(device), TD_FixPts.to(device)

        optimizer.zero_grad()
        outputs = model(images)  # 🔹 Predicted saliency map
        
        loss = -2*loss_fn(outputs,TD_maps,loss_type='cc')\
                        -1*loss_fn(outputs,TD_maps,loss_type='sim')+\
                        10*loss_fn(outputs,TD_maps,loss_type='kldiv')-1*loss_fn(outputs,TD_FixPts,loss_type='nss')
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader):.4f}")
# Out:
# backbone.0.weight: True
# backbone.1.weight: True
# backbone.1.bias: True
# backbone.4.0.conv1.weight: True
# backbone.4.0.bn1.weight: True
# backbone.4.0.bn1.bias: True
# backbone.4.0.conv2.weight: True
# backbone.4.0.bn2.weight: True
# backbone.4.0.bn2.bias: True
# backbone.4.0.conv3.weight: True
# backbone.4.0.bn3.weight: True
# backbone.4.0.bn3.bias: True
# backbone.4.0.downsample.0.weight: True
# backbone.4.0.downsample.1.weight: True
# backbone.4.0.downsample.1.bias: True
# backbone.4.1.conv1.weight: True
# backbone.4.1.bn1.weight: True
# backbone.4.1.bn1.bias: True
# backbone.4.1.conv2.weight: True
# backbone.4.1.bn2.weight: True
# backbone.4.1.bn2.bias: True
# backbone.4.1.conv3.weight: True
# backbone.4.1.bn3.weight: True
# backbone.4.1.bn3.bias: True
# backbone.4.2.conv1.weight: True
# backbone.4.2.bn1.weight: True
# backbone.4.2.bn1.bias: True
# backbone.4.2.conv2.weight: True
# backbone.4.2.bn2.weight: True
# backbone.4.2.bn2.bias: True
# backbone.4.2.conv3.weight: True
# backbone.4.2.bn3.weight: True
# backbone.4.2.bn3.bias: True
# backbone.5.0.conv1.weight: True
# backbone.5.0.bn1.weight: True
# backbone.5.0.bn1.bias: True
# backbone.5.0.conv2.weight: True
# backbone.5.0.bn2.weight: True
# backbone.5.0.bn2.bias: True
# backbone.5.0.conv3.weight: True
# backbone.5.0.bn3.weight: True
# backbone.5.0.bn3.bias: True
# backbone.5.0.downsample.0.weight: True
# backbone.5.0.downsample.1.weight: True
# backbone.5.0.downsample.1.bias: True
# backbone.5.1.conv1.weight: True
# backbone.5.1.bn1.weight: True
# backbone.5.1.bn1.bias: True
# backbone.5.1.conv2.weight: True
# backbone.5.1.bn2.weight: True
# backbone.5.1.bn2.bias: True
# backbone.5.1.conv3.weight: True
# backbone.5.1.bn3.weight: True
# backbone.5.1.bn3.bias: True
# backbone.5.2.conv1.weight: True
# backbone.5.2.bn1.weight: True
# backbone.5.2.bn1.bias: True
# backbone.5.2.conv2.weight: True
# backbone.5.2.bn2.weight: True
# backbone.5.2.bn2.bias: True
# backbone.5.2.conv3.weight: True
# backbone.5.2.bn3.weight: True
# backbone.5.2.bn3.bias: True
# backbone.5.3.conv1.weight: True
# backbone.5.3.bn1.weight: True
# backbone.5.3.bn1.bias: True
# backbone.5.3.conv2.weight: True
# backbone.5.3.bn2.weight: True
# backbone.5.3.bn2.bias: True
# backbone.5.3.conv3.weight: True
# backbone.5.3.bn3.weight: True
# backbone.5.3.bn3.bias: True
# backbone.6.0.conv1.weight: True
# backbone.6.0.bn1.weight: True
# backbone.6.0.bn1.bias: True
# backbone.6.0.conv2.weight: True
# backbone.6.0.bn2.weight: True
# backbone.6.0.bn2.bias: True
# backbone.6.0.conv3.weight: True
# backbone.6.0.bn3.weight: True
# backbone.6.0.bn3.bias: True
# backbone.6.0.downsample.0.weight: True
# backbone.6.0.downsample.1.weight: True
# backbone.6.0.downsample.1.bias: True
# backbone.6.1.conv1.weight: True
# backbone.6.1.bn1.weight: True
# backbone.6.1.bn1.bias: True
# backbone.6.1.conv2.weight: True
# backbone.6.1.bn2.weight: True
# backbone.6.1.bn2.bias: True
# backbone.6.1.conv3.weight: True
# backbone.6.1.bn3.weight: True
# backbone.6.1.bn3.bias: True
# backbone.6.2.conv1.weight: True
# backbone.6.2.bn1.weight: True
# backbone.6.2.bn1.bias: True
# backbone.6.2.conv2.weight: True
# backbone.6.2.bn2.weight: True
# backbone.6.2.bn2.bias: True
# backbone.6.2.conv3.weight: True
# backbone.6.2.bn3.weight: True
# backbone.6.2.bn3.bias: True
# backbone.6.3.conv1.weight: True
# backbone.6.3.bn1.weight: True
# backbone.6.3.bn1.bias: True
# backbone.6.3.conv2.weight: True
# backbone.6.3.bn2.weight: True
# backbone.6.3.bn2.bias: True
# backbone.6.3.conv3.weight: True
# backbone.6.3.bn3.weight: True
# backbone.6.3.bn3.bias: True
# backbone.6.4.conv1.weight: True
# backbone.6.4.bn1.weight: True
# backbone.6.4.bn1.bias: True
# backbone.6.4.conv2.weight: True
# backbone.6.4.bn2.weight: True
# backbone.6.4.bn2.bias: True
# backbone.6.4.conv3.weight: True
# backbone.6.4.bn3.weight: True
# backbone.6.4.bn3.bias: True
# backbone.6.5.conv1.weight: True
# backbone.6.5.bn1.weight: True
# backbone.6.5.bn1.bias: True
# backbone.6.5.conv2.weight: True
# backbone.6.5.bn2.weight: True
# backbone.6.5.bn2.bias: True
# backbone.6.5.conv3.weight: True
# backbone.6.5.bn3.weight: True
# backbone.6.5.bn3.bias: True
# backbone.7.0.conv1.weight: True
# backbone.7.0.bn1.weight: True
# backbone.7.0.bn1.bias: True
# backbone.7.0.conv2.weight: True
# backbone.7.0.bn2.weight: True
# backbone.7.0.bn2.bias: True
# backbone.7.0.conv3.weight: True
# backbone.7.0.bn3.weight: True
# backbone.7.0.bn3.bias: True
# backbone.7.0.downsample.0.weight: True
# backbone.7.0.downsample.1.weight: True
# backbone.7.0.downsample.1.bias: True
# backbone.7.1.conv1.weight: True
# backbone.7.1.bn1.weight: True
# backbone.7.1.bn1.bias: True
# backbone.7.1.conv2.weight: True
# backbone.7.1.bn2.weight: True
# backbone.7.1.bn2.bias: True
# backbone.7.1.conv3.weight: True
# backbone.7.1.bn3.weight: True
# backbone.7.1.bn3.bias: True
# backbone.7.2.conv1.weight: True
# backbone.7.2.bn1.weight: True
# backbone.7.2.bn1.bias: True
# backbone.7.2.conv2.weight: True
# backbone.7.2.bn2.weight: True
# backbone.7.2.bn2.bias: True
# backbone.7.2.conv3.weight: True
# backbone.7.2.bn3.weight: True
# backbone.7.2.bn3.bias: True
# transformer.cls_token: True
# transformer.pos_embed: True
# transformer.patch_embed.proj.weight: True
# transformer.patch_embed.proj.bias: True
# transformer.blocks.0.norm1.weight: True
# transformer.blocks.0.norm1.bias: True
# transformer.blocks.0.attn.qkv.weight: True
# transformer.blocks.0.attn.qkv.bias: True
# transformer.blocks.0.attn.proj.weight: True
# transformer.blocks.0.attn.proj.bias: True
# transformer.blocks.0.norm2.weight: True
# transformer.blocks.0.norm2.bias: True
# transformer.blocks.0.mlp.fc1.weight: True
# transformer.blocks.0.mlp.fc1.bias: True
# transformer.blocks.0.mlp.fc2.weight: True
# transformer.blocks.0.mlp.fc2.bias: True
# transformer.blocks.1.norm1.weight: True
# transformer.blocks.1.norm1.bias: True
# transformer.blocks.1.attn.qkv.weight: True
# transformer.blocks.1.attn.qkv.bias: True
# transformer.blocks.1.attn.proj.weight: True
# transformer.blocks.1.attn.proj.bias: True
# transformer.blocks.1.norm2.weight: True
# transformer.blocks.1.norm2.bias: True
# transformer.blocks.1.mlp.fc1.weight: True
# transformer.blocks.1.mlp.fc1.bias: True
# transformer.blocks.1.mlp.fc2.weight: True
# transformer.blocks.1.mlp.fc2.bias: True
# transformer.blocks.2.norm1.weight: True
# transformer.blocks.2.norm1.bias: True
# transformer.blocks.2.attn.qkv.weight: True
# transformer.blocks.2.attn.qkv.bias: True
# transformer.blocks.2.attn.proj.weight: True
# transformer.blocks.2.attn.proj.bias: True
# transformer.blocks.2.norm2.weight: True
# transformer.blocks.2.norm2.bias: True
# transformer.blocks.2.mlp.fc1.weight: True
# transformer.blocks.2.mlp.fc1.bias: True
# transformer.blocks.2.mlp.fc2.weight: True
# transformer.blocks.2.mlp.fc2.bias: True
# transformer.blocks.3.norm1.weight: True
# transformer.blocks.3.norm1.bias: True
# transformer.blocks.3.attn.qkv.weight: True
# transformer.blocks.3.attn.qkv.bias: True
# transformer.blocks.3.attn.proj.weight: True
# transformer.blocks.3.attn.proj.bias: True
# transformer.blocks.3.norm2.weight: True
# transformer.blocks.3.norm2.bias: True
# transformer.blocks.3.mlp.fc1.weight: True
# transformer.blocks.3.mlp.fc1.bias: True
# transformer.blocks.3.mlp.fc2.weight: True
# transformer.blocks.3.mlp.fc2.bias: True
# transformer.blocks.4.norm1.weight: True
# transformer.blocks.4.norm1.bias: True
# transformer.blocks.4.attn.qkv.weight: True
# transformer.blocks.4.attn.qkv.bias: True
# transformer.blocks.4.attn.proj.weight: True
# transformer.blocks.4.attn.proj.bias: True
# transformer.blocks.4.norm2.weight: True
# transformer.blocks.4.norm2.bias: True
# transformer.blocks.4.mlp.fc1.weight: True
# transformer.blocks.4.mlp.fc1.bias: True
# transformer.blocks.4.mlp.fc2.weight: True
# transformer.blocks.4.mlp.fc2.bias: True
# transformer.blocks.5.norm1.weight: True
# transformer.blocks.5.norm1.bias: True
# transformer.blocks.5.attn.qkv.weight: True
# transformer.blocks.5.attn.qkv.bias: True
# transformer.blocks.5.attn.proj.weight: True
# transformer.blocks.5.attn.proj.bias: True
# transformer.blocks.5.norm2.weight: True
# transformer.blocks.5.norm2.bias: True
# transformer.blocks.5.mlp.fc1.weight: True
# transformer.blocks.5.mlp.fc1.bias: True
# transformer.blocks.5.mlp.fc2.weight: True
# transformer.blocks.5.mlp.fc2.bias: True
# transformer.blocks.6.norm1.weight: True
# transformer.blocks.6.norm1.bias: True
# transformer.blocks.6.attn.qkv.weight: True
# transformer.blocks.6.attn.qkv.bias: True
# transformer.blocks.6.attn.proj.weight: True
# transformer.blocks.6.attn.proj.bias: True
# transformer.blocks.6.norm2.weight: True
# transformer.blocks.6.norm2.bias: True
# transformer.blocks.6.mlp.fc1.weight: True
# transformer.blocks.6.mlp.fc1.bias: True
# transformer.blocks.6.mlp.fc2.weight: True
# transformer.blocks.6.mlp.fc2.bias: True
# transformer.blocks.7.norm1.weight: True
# transformer.blocks.7.norm1.bias: True
# transformer.blocks.7.attn.qkv.weight: True
# transformer.blocks.7.attn.qkv.bias: True
# transformer.blocks.7.attn.proj.weight: True
# transformer.blocks.7.attn.proj.bias: True
# transformer.blocks.7.norm2.weight: True
# transformer.blocks.7.norm2.bias: True
# transformer.blocks.7.mlp.fc1.weight: True
# transformer.blocks.7.mlp.fc1.bias: True
# transformer.blocks.7.mlp.fc2.weight: True
# transformer.blocks.7.mlp.fc2.bias: True
# transformer.blocks.8.norm1.weight: True
# transformer.blocks.8.norm1.bias: True
# transformer.blocks.8.attn.qkv.weight: True
# transformer.blocks.8.attn.qkv.bias: True
# transformer.blocks.8.attn.proj.weight: True
# transformer.blocks.8.attn.proj.bias: True
# transformer.blocks.8.norm2.weight: True
# transformer.blocks.8.norm2.bias: True
# transformer.blocks.8.mlp.fc1.weight: True
# transformer.blocks.8.mlp.fc1.bias: True
# transformer.blocks.8.mlp.fc2.weight: True
# transformer.blocks.8.mlp.fc2.bias: True
# transformer.blocks.9.norm1.weight: True
# transformer.blocks.9.norm1.bias: True
# transformer.blocks.9.attn.qkv.weight: True
# transformer.blocks.9.attn.qkv.bias: True
# transformer.blocks.9.attn.proj.weight: True
# transformer.blocks.9.attn.proj.bias: True
# transformer.blocks.9.norm2.weight: True
# transformer.blocks.9.norm2.bias: True
# transformer.blocks.9.mlp.fc1.weight: True
# transformer.blocks.9.mlp.fc1.bias: True
# transformer.blocks.9.mlp.fc2.weight: True
# transformer.blocks.9.mlp.fc2.bias: True
# transformer.blocks.10.norm1.weight: True
# transformer.blocks.10.norm1.bias: True
# transformer.blocks.10.attn.qkv.weight: True
# transformer.blocks.10.attn.qkv.bias: True
# transformer.blocks.10.attn.proj.weight: True
# transformer.blocks.10.attn.proj.bias: True
# transformer.blocks.10.norm2.weight: True
# transformer.blocks.10.norm2.bias: True
# transformer.blocks.10.mlp.fc1.weight: True
# transformer.blocks.10.mlp.fc1.bias: True
# transformer.blocks.10.mlp.fc2.weight: True
# transformer.blocks.10.mlp.fc2.bias: True
# transformer.blocks.11.norm1.weight: True
# transformer.blocks.11.norm1.bias: True
# transformer.blocks.11.attn.qkv.weight: True
# transformer.blocks.11.attn.qkv.bias: True
# transformer.blocks.11.attn.proj.weight: True
# transformer.blocks.11.attn.proj.bias: True
# transformer.blocks.11.norm2.weight: True
# transformer.blocks.11.norm2.bias: True
# transformer.blocks.11.mlp.fc1.weight: True
# transformer.blocks.11.mlp.fc1.bias: True
# transformer.blocks.11.mlp.fc2.weight: True
# transformer.blocks.11.mlp.fc2.bias: True
# transformer.norm.weight: True
# transformer.norm.bias: True
# projection.weight: True
# projection.bias: True
# encoder.layers.0.self_attn.in_proj_weight: True
# encoder.layers.0.self_attn.in_proj_bias: True
# encoder.layers.0.self_attn.out_proj.weight: True
# encoder.layers.0.self_attn.out_proj.bias: True
# encoder.layers.0.linear1.weight: True
# encoder.layers.0.linear1.bias: True
# encoder.layers.0.linear2.weight: True
# encoder.layers.0.linear2.bias: True
# encoder.layers.0.norm1.weight: True
# encoder.layers.0.norm1.bias: True
# encoder.layers.0.norm2.weight: True
# encoder.layers.0.norm2.bias: True
# encoder.layers.1.self_attn.in_proj_weight: True
# encoder.layers.1.self_attn.in_proj_bias: True
# encoder.layers.1.self_attn.out_proj.weight: True
# encoder.layers.1.self_attn.out_proj.bias: True
# encoder.layers.1.linear1.weight: True
# encoder.layers.1.linear1.bias: True
# encoder.layers.1.linear2.weight: True
# encoder.layers.1.linear2.bias: True
# encoder.layers.1.norm1.weight: True
# encoder.layers.1.norm1.bias: True
# encoder.layers.1.norm2.weight: True
# encoder.layers.1.norm2.bias: True
# encoder.layers.2.self_attn.in_proj_weight: True
# encoder.layers.2.self_attn.in_proj_bias: True
# encoder.layers.2.self_attn.out_proj.weight: True
# encoder.layers.2.self_attn.out_proj.bias: True
# encoder.layers.2.linear1.weight: True
# encoder.layers.2.linear1.bias: True
# encoder.layers.2.linear2.weight: True
# encoder.layers.2.linear2.bias: True
# encoder.layers.2.norm1.weight: True
# encoder.layers.2.norm1.bias: True
# encoder.layers.2.norm2.weight: True
# encoder.layers.2.norm2.bias: True
# encoder.layers.3.self_attn.in_proj_weight: True
# encoder.layers.3.self_attn.in_proj_bias: True
# encoder.layers.3.self_attn.out_proj.weight: True
# encoder.layers.3.self_attn.out_proj.bias: True
# encoder.layers.3.linear1.weight: True
# encoder.layers.3.linear1.bias: True
# encoder.layers.3.linear2.weight: True
# encoder.layers.3.linear2.bias: True
# encoder.layers.3.norm1.weight: True
# encoder.layers.3.norm1.bias: True
# encoder.layers.3.norm2.weight: True
# encoder.layers.3.norm2.bias: True
# upsample1.weight: True
# upsample1.bias: True
# upsample2.weight: True
# upsample2.bias: True
# upsample3.weight: True
# upsample3.bias: True
# upsample4.weight: True
# upsample4.bias: True
# Epoch 1/10
# ----------
# Epoch [1/10], Loss: 9.9277
# Epoch 2/10
# ----------
# Epoch [2/10], Loss: 16.3776
# Epoch 3/10
# ----------
# Epoch [3/10], Loss: 19.1272
# Epoch 4/10
# ----------
# Epoch [4/10], Loss: 19.1359
# Epoch 5/10
# ----------
# Epoch [5/10], Loss: 17.5464
# Epoch 6/10
# ----------
# Epoch [6/10], Loss: 15.1196
# Epoch 7/10
# ----------
# Epoch [7/10], Loss: 12.2859
# Epoch 8/10
# ----------
# Epoch [8/10], Loss: 9.2373
# Epoch 9/10
# ----------
# Epoch [9/10], Loss: 6.0440
# Epoch 10/10
# ----------
# Epoch [10/10], Loss: 2.6760

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

model.eval()  # Set the model to evaluation mode to disable dropout

# Ensure the save directory exists
os.makedirs(save_dir, exist_ok=True)

# Get a batch from the validation set (or train set) to predict the final saliency map
with torch.no_grad():
    for idx, (images, saliency_maps, fixation_maps) in enumerate(train_loader):
        images = images.to(device)

        outputs = model(images)

        for i in range(images.size(0)):
            output_map = outputs[i].cpu().detach().numpy()
            output_map = np.squeeze(output_map)

            plt.imshow(output_map, cmap='jet')
            plt.axis('off')
            plt.colorbar()

            image_filename = f"{idx * len(images) + i + 1}_predicted_saliency_map_epoch_{epoch+1}.png"
            plt.savefig(os.path.join(save_dir, image_filename), bbox_inches='tight')
            plt.close()
